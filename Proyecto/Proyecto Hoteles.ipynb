# %% [markdown]
# # Proyecto Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data=pd.read_csv('data/hoteles.csv')

# %%
data
# Out:
#                                                Nombres              Tipo  \
# 0                                        Costa Paraiso             Hotel
# 1                              Hosteria Puerto Gaviota             Hotel
# 2                                           El Marqués             Hotel
# 3                                         Club del Sol            Resort
# 4                                               Carluz             Hotel
# 5                                           Cielo Azul             Hotel
# 6                                       Torino Equador             Hotel
# 7                     Espectacular Vista Frente Al Mar  Casa/Apartamento
# 8                                              Ipanema             Hotel
# 9                                    Cabanas Camarones  Casa/Apartamento
# 10                                           Saiananda             Hotel
# 11                                            Balandra             Hotel
# 12                                          Hostal Sky             Hotel
# 13                                   Suite San Antonio             Hotel
# 14                                 Tiki Trip Montanita  Casa/Apartamento
# 15                                   Montañita Estates       Apartahotel
# 16                             Apartamento Arena Plaza  Casa/Apartamento
# 17                                          Casa Coral  Casa/Apartamento
# 18                                           Arco Iris  Casa/Apartamento
# 19                             Casa Vacacional Blanchi  Casa/Apartamento
# 20            Apartamento En Atacames Con Vista Al Mar  Casa/Apartamento
# 21                                             Elicios             Hotel
# 22                                         Aldea Playa             Hotel
# 23                                 Bellavista Bellevue  Casa/Apartamento
# 24                                Blackpoint Ballenita             Hotel
# 25                                       Beach Escapes  Casa/Apartamento
# 26                                  Hosteria Bluebeach             Hotel
# 27                                     Galeria's Beach             Hotel
# 28                                 Hostal Como En Casa   Albergue/Hostel
# 29                                        Ronabi Beach             Hotel
# ..                                                 ...               ...
# 230                                    Casa Vacacional  Casa/Apartamento
# 231                                 Hosteria Bluebeach             Hotel
# 232                                Hostal Como En Casa   Albergue/Hostel
# 233                                         Rio Suites           Pensión
# 234                                      Diamond Beach  Casa/Apartamento
# 235                                      Grand Pacific             Hotel
# 236                                           Casaymar             Hotel
# 237      Frente a la playa de Bliss Más cerca de Quito  Casa/Apartamento
# 238                           Suit Condominio Camboriu  Casa/Apartamento
# 239                                  Ecológica El Faro   Bed & Breakfast
# 240    Exclusivo Condo - La mejor ubicación en Salinas  Casa/Apartamento
# 241                                      Hostal Haziel            Hostal
# 242                                      Chaqana Lodge             Hotel
# 243                                            Ipanema             Hotel
# 244                              La Ideota Guest House             Hotel
# 245                                             Caridi             Hotel
# 246                                       Almond Beach             Hotel
# 247  Tonsupa, Hermoso Departamento Familiar Sector ...             Hotel
# 248                              Diamond Beach Tonsupa             Hotel
# 249                                      Diamond Beach             Hotel
# 250                                           Isabella             Hotel
# 251                                              Cocos   Albergue/Hostel
# 252                                       SP Montañita             Hotel
# 253                          Hostería Estrella Del Mar  Casa/Apartamento
# 254                                 Las Palmas Del Mar   Bed & Breakfast
# 255                                          La Bocana             Hotel
# 256                              Cabanas Punta Carnero  Casa/Apartamento
# 257                                   Riveri Salinas 6             Hotel
# 258                                        El Marinero             Hotel
# 259                                        Palmira Inn             Hotel
#
#     Precios Rating                                          Ubicacion  \
# 0       $63    7.3         Atacames, a 2.5 km de: centro de la ciudad
# 1      $125    8.2         Atacames, a 4.8 km de: centro de la ciudad
# 2      $106    8.4         Atacames, a 1.8 km de: centro de la ciudad
# 3       $99    7.8         Atacames, a 2.3 km de: centro de la ciudad
# 4      $150    8.0         Atacames, a 2.2 km de: centro de la ciudad
# 5      $120    8.2         Atacames, a 2.3 km de: centro de la ciudad
# 6       $56    7.3         Atacames, a 4.3 km de: centro de la ciudad
# 7      $500      /        Ballenita, a 0.4 km de: centro de la ciudad
# 8       $50      /                   Salinas, a 10.4 km de: Ballenita
# 9       $60    8.2                            Canoa, junto a la playa
# 10      $47    8.1  Bahía de Caráquez, a 4.7 km de: centro de la c...
# 11     $119    8.8                        Manta, A 0.3 km de la playa
# 12      $45      /                        Manta, A 0.3 km de la playa
# 13      $60    7.4         Mompiche, a 0.5 km de: centro de la ciudad
# 14      $60    7.7        Montañita, a 0.5 km de: centro de la ciudad
# 15     $111    8.0        Montañita, a 0.6 km de: centro de la ciudad
# 16     $170      /         Atacames, a 6.1 km de: centro de la ciudad
# 17     $255      /         Atacames, a 3.1 km de: centro de la ciudad
# 18      $80      /         Atacames, a 2.5 km de: centro de la ciudad
# 19      $62      /        Atacames, a 15.7 km de: centro de la ciudad
# 20     $150      /         Atacames, a 2.5 km de: centro de la ciudad
# 21      $49      /         Atacames, a 2.3 km de: centro de la ciudad
# 22      $70      /         Atacames, a 2.3 km de: centro de la ciudad
# 23      $35    8.4        Ballenita, a 0.6 km de: centro de la ciudad
# 24     $118      /        Ballenita, a 0.3 km de: centro de la ciudad
# 25      $40      /        Ballenita, a 0.5 km de: centro de la ciudad
# 26      $48      /                   Salinas, a 10.4 km de: Ballenita
# 27      $80      /                   Salinas, a 10.5 km de: Ballenita
# 28      $74      /                   Salinas, a 10.6 km de: Ballenita
# 29      $49      /                   Salinas, a 10.7 km de: Ballenita
# ..      ...    ...                                                ...
# 230    $250      /                      Salinas, A 0.3 km de la playa
# 231     $48      /                      Salinas, A 0.2 km de la playa
# 232     $74      /          Salinas, a 2.4 km de: centro de la ciudad
# 233     $42    8.2          Tonsupa, a 1.8 km de: centro de la ciudad
# 234    $180      /          Tonsupa, a 1.2 km de: centro de la ciudad
# 235    $127      /          Tonsupa, a 2.0 km de: centro de la ciudad
# 236     $80    8.0                      Tonsupa, A 0.6 km de la playa
# 237    $175      /          Tonsupa, a 0.0 km de: centro de la ciudad
# 238     $79    8.3          Salinas, a 0.6 km de: centro de la ciudad
# 239    $135    8.2          Salinas, a 1.3 km de: centro de la ciudad
# 240    $250      /          Salinas, a 0.0 km de: centro de la ciudad
# 241     $85    7.6          Salinas, a 1.6 km de: centro de la ciudad
# 242     $60    8.2                      Salinas, A 0.2 km de la playa
# 243     $50      /                      Salinas, A 0.2 km de la playa
# 244     $57      /          Salinas, a 0.5 km de: centro de la ciudad
# 245     $80      /          Salinas, a 0.8 km de: centro de la ciudad
# 246     $55      /                      Tonsupa, A 0.7 km de la playa
# 247    $170      /                      Tonsupa, A 0.7 km de la playa
# 248    $310      /                      Tonsupa, A 0.1 km de la playa
# 249    $250      /          Tonsupa, a 2.0 km de: centro de la ciudad
# 250     $63    7.8                      Salinas, A 0.3 km de la playa
# 251     $70    7.4                          Salinas, junto a la playa
# 252    $117      /                      Salinas, A 0.2 km de la playa
# 253    $110    8.0                      Salinas, A 0.2 km de la playa
# 254     $65    8.8                      Salinas, A 0.1 km de la playa
# 255     $60      /                      Tonsupa, A 0.7 km de la playa
# 256    $500      /                      Salinas, A 0.5 km de la playa
# 257    $367      /          Salinas, a 3.7 km de: centro de la ciudad
# 258    $140      /                      Salinas, A 0.5 km de la playa
# 259    $120      /                      Salinas, A 0.1 km de la playa
#
#            Pagina
# 0     Hoteles.com
# 1     Hoteles.com
# 2    Despegar.com
# 3     Booking.com
# 4     Booking.com
# 5     Booking.com
# 6     Hoteles.com
# 7     Hoteles.com
# 8     Hoteles.com
# 9     Booking.com
# 10   Despegar.com
# 11    Hoteles.com
# 12    Hoteles.com
# 13    Hoteles.com
# 14    Booking.com
# 15    Hoteles.com
# 16    Booking.com
# 17    Booking.com
# 18    Booking.com
# 19    Booking.com
# 20    Booking.com
# 21   Despegar.com
# 22    Booking.com
# 23    Booking.com
# 24    Booking.com
# 25    Booking.com
# 26    Booking.com
# 27    Booking.com
# 28    Booking.com
# 29    Booking.com
# ..            ...
# 230   Booking.com
# 231   Booking.com
# 232   Booking.com
# 233   Booking.com
# 234   Hoteles.com
# 235   Hoteles.com
# 236   Booking.com
# 237      HomeAway
# 238   Booking.com
# 239   Booking.com
# 240      HomeAway
# 241   Booking.com
# 242   Booking.com
# 243   Hoteles.com
# 244   Booking.com
# 245   Booking.com
# 246   Booking.com
# 247   Booking.com
# 248   Booking.com
# 249   Booking.com
# 250   Booking.com
# 251   Booking.com
# 252  Despegar.com
# 253   Booking.com
# 254   Booking.com
# 255   Booking.com
# 256   Booking.com
# 257   Booking.com
# 258   Booking.com
# 259   Booking.com
#
# [260 rows x 6 columns]

# %%
try:
    with open('./data/hoteles.csv')as archivo_abierto:
        nombres = []   
        arreglo_lineas_archivo = archivo_abierto.readlines()
        for linea in arreglo_lineas_archivo:
            data = linea.split(',')
            nombres.append(data[0])
except Exception():
    print("No se pudo leer el archivo")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-11beb9f5aeb8> in <module>()
#       4
# ----> 5         arreglo_lineas_archivo = archivo_abierto.readlines()
#       6         for linea in arreglo_lineas_archivo:
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 872: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-11beb9f5aeb8> in <module>()
#       9
#      10
# ---> 11 except Exception():
#      12     print("No se pudo leer el archivo")
#
# TypeError: catching classes that do not inherit from BaseException is not allowed
