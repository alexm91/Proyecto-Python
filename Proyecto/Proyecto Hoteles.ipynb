# %% [markdown]
# # Proyecto Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('data/hoteles.csv')
data
# Out:
#                                              Nombres  \
# 0                                      Costa Paraiso
# 1                            Hosteria Puerto Gaviota
# 2                                         El Marqués
# 3                                       Club del Sol
# 4                                             Carluz
# 5                                         Cielo Azul
# 6                                     Torino Equador
# 7                   Espectacular Vista Frente Al Mar
# 8                                            Ipanema
# 9                                  Cabanas Camarones
# 10                                         Saiananda
# 11                                          Balandra
# 12                                        Hostal Sky
# 13                                 Suite San Antonio
# 14                               Tiki Trip Montanita
# 15                                 Montañita Estates
# 16                           Apartamento Arena Plaza
# 17                                        Casa Coral
# 18                                         Arco Iris
# 19                           Casa Vacacional Blanchi
# 20          Apartamento En Atacames Con Vista Al Mar
# 21                                           Elicios
# 22                                       Aldea Playa
# 23                               Bellavista Bellevue
# 24                              Blackpoint Ballenita
# 25                                     Beach Escapes
# 26                                Hosteria Bluebeach
# 27                                   Galeria's Beach
# 28                               Hostal Como En Casa
# 29                                      Ronabi Beach
# ..                                               ...
# 230                                  Casa Vacacional
# 231                               Hosteria Bluebeach
# 232                              Hostal Como En Casa
# 233                                       Rio Suites
# 234                                    Diamond Beach
# 235                                    Grand Pacific
# 236                                         Casaymar
# 237    Frente a la playa de Bliss Más cerca de Quito
# 238                         Suit Condominio Camboriu
# 239                                Ecológica El Faro
# 240  Exclusivo Condo - La mejor ubicación en Salinas
# 241                                    Hostal Haziel
# 242                                    Chaqana Lodge
# 243                                          Ipanema
# 244                            La Ideota Guest House
# 245                                           Caridi
# 246                                     Almond Beach
# 247                                          Tonsupa
# 248                            Diamond Beach Tonsupa
# 249                                    Diamond Beach
# 250                                         Isabella
# 251                                            Cocos
# 252                                     SP Montañita
# 253                        Hostería Estrella Del Mar
# 254                               Las Palmas Del Mar
# 255                                        La Bocana
# 256                            Cabanas Punta Carnero
# 257                                 Riveri Salinas 6
# 258                                      El Marinero
# 259                                      Palmira Inn
#
#                                                   Tipo Precios Rating  \
# 0                                                Hotel     $63    7.3
# 1                                                Hotel    $125    8.2
# 2                                                Hotel    $106    8.4
# 3                                               Resort     $99    7.8
# 4                                                Hotel    $150    8.0
# 5                                                Hotel    $120    8.2
# 6                                                Hotel     $56    7.3
# 7                                     Casa/Apartamento    $500      /
# 8                                                Hotel     $50      /
# 9                                     Casa/Apartamento     $60    8.2
# 10                                               Hotel     $47    8.1
# 11                                               Hotel    $119    8.8
# 12                                               Hotel     $45      /
# 13                                               Hotel     $60    7.4
# 14                                    Casa/Apartamento     $60    7.7
# 15                                         Apartahotel    $111    8.0
# 16                                    Casa/Apartamento    $170      /
# 17                                    Casa/Apartamento    $255      /
# 18                                    Casa/Apartamento     $80      /
# 19                                    Casa/Apartamento     $62      /
# 20                                    Casa/Apartamento    $150      /
# 21                                               Hotel     $49      /
# 22                                               Hotel     $70      /
# 23                                    Casa/Apartamento     $35    8.4
# 24                                               Hotel    $118      /
# 25                                    Casa/Apartamento     $40      /
# 26                                               Hotel     $48      /
# 27                                               Hotel     $80      /
# 28                                     Albergue/Hostel     $74      /
# 29                                               Hotel     $49      /
# ..                                                 ...     ...    ...
# 230                                   Casa/Apartamento    $250      /
# 231                                              Hotel     $48      /
# 232                                    Albergue/Hostel     $74      /
# 233                                            Pensión     $42    8.2
# 234                                   Casa/Apartamento    $180      /
# 235                                              Hotel    $127      /
# 236                                              Hotel     $80    8.0
# 237                                   Casa/Apartamento    $175      /
# 238                                   Casa/Apartamento     $79    8.3
# 239                                    Bed & Breakfast    $135    8.2
# 240                                   Casa/Apartamento    $250      /
# 241                                             Hostal     $85    7.6
# 242                                              Hotel     $60    8.2
# 243                                              Hotel     $50      /
# 244                                              Hotel     $57      /
# 245                                              Hotel     $80      /
# 246                                              Hotel     $55      /
# 247   Hermoso Departamento Familiar Sector Club Del...    $170      /
# 248                                              Hotel    $310      /
# 249                                              Hotel    $250      /
# 250                                              Hotel     $63    7.8
# 251                                    Albergue/Hostel     $70    7.4
# 252                                              Hotel    $117      /
# 253                                   Casa/Apartamento    $110    8.0
# 254                                    Bed & Breakfast     $65    8.8
# 255                                              Hotel     $60      /
# 256                                   Casa/Apartamento    $500      /
# 257                                              Hotel    $367      /
# 258                                              Hotel    $140      /
# 259                                              Hotel    $120      /
#
#                  Lugar                           Ubicacion        Pagina
# 0             Atacames    a 2.5 km de: centro de la ciudad   Hoteles.com
# 1             Atacames    a 4.8 km de: centro de la ciudad   Hoteles.com
# 2             Atacames    a 1.8 km de: centro de la ciudad  Despegar.com
# 3             Atacames    a 2.3 km de: centro de la ciudad   Booking.com
# 4             Atacames    a 2.2 km de: centro de la ciudad   Booking.com
# 5             Atacames    a 2.3 km de: centro de la ciudad   Booking.com
# 6             Atacames    a 4.3 km de: centro de la ciudad   Hoteles.com
# 7            Ballenita    a 0.4 km de: centro de la ciudad   Hoteles.com
# 8              Salinas             a 10.4 km de: Ballenita   Hoteles.com
# 9                Canoa                    junto a la playa   Booking.com
# 10   Bahía de Caráquez    a 4.7 km de: centro de la ciudad  Despegar.com
# 11               Manta                a 0.3 km de la playa   Hoteles.com
# 12               Manta                a 0.3 km de la playa   Hoteles.com
# 13            Mompiche    a 0.5 km de: centro de la ciudad   Hoteles.com
# 14           Montañita    a 0.5 km de: centro de la ciudad   Booking.com
# 15           Montañita    a 0.6 km de: centro de la ciudad   Hoteles.com
# 16            Atacames    a 6.1 km de: centro de la ciudad   Booking.com
# 17            Atacames    a 3.1 km de: centro de la ciudad   Booking.com
# 18            Atacames    a 2.5 km de: centro de la ciudad   Booking.com
# 19            Atacames   a 15.7 km de: centro de la ciudad   Booking.com
# 20            Atacames    a 2.5 km de: centro de la ciudad   Booking.com
# 21            Atacames    a 2.3 km de: centro de la ciudad  Despegar.com
# 22            Atacames    a 2.3 km de: centro de la ciudad   Booking.com
# 23           Ballenita    a 0.6 km de: centro de la ciudad   Booking.com
# 24           Ballenita    a 0.3 km de: centro de la ciudad   Booking.com
# 25           Ballenita    a 0.5 km de: centro de la ciudad   Booking.com
# 26             Salinas             a 10.4 km de: Ballenita   Booking.com
# 27             Salinas             a 10.5 km de: Ballenita   Booking.com
# 28             Salinas             a 10.6 km de: Ballenita   Booking.com
# 29             Salinas             a 10.7 km de: Ballenita   Booking.com
# ..                 ...                                 ...           ...
# 230            Salinas                A 0.3 km de la playa   Booking.com
# 231            Salinas                A 0.2 km de la playa   Booking.com
# 232            Salinas    a 2.4 km de: centro de la ciudad   Booking.com
# 233            Tonsupa    a 1.8 km de: centro de la ciudad   Booking.com
# 234            Tonsupa    a 1.2 km de: centro de la ciudad   Hoteles.com
# 235            Tonsupa    a 2.0 km de: centro de la ciudad   Hoteles.com
# 236            Tonsupa                A 0.6 km de la playa   Booking.com
# 237            Tonsupa    a 0.0 km de: centro de la ciudad      HomeAway
# 238            Salinas    a 0.6 km de: centro de la ciudad   Booking.com
# 239            Salinas    a 1.3 km de: centro de la ciudad   Booking.com
# 240            Salinas    a 0.0 km de: centro de la ciudad      HomeAway
# 241            Salinas    a 1.6 km de: centro de la ciudad   Booking.com
# 242            Salinas                A 0.2 km de la playa   Booking.com
# 243            Salinas                A 0.2 km de la playa   Hoteles.com
# 244            Salinas    a 0.5 km de: centro de la ciudad   Booking.com
# 245            Salinas    a 0.8 km de: centro de la ciudad   Booking.com
# 246            Tonsupa                A 0.7 km de la playa   Booking.com
# 247            Tonsupa                A 0.7 km de la playa   Booking.com
# 248            Tonsupa                A 0.1 km de la playa   Booking.com
# 249            Tonsupa    a 2.0 km de: centro de la ciudad   Booking.com
# 250            Salinas                A 0.3 km de la playa   Booking.com
# 251            Salinas                    junto a la playa   Booking.com
# 252            Salinas                A 0.2 km de la playa  Despegar.com
# 253            Salinas                A 0.2 km de la playa   Booking.com
# 254            Salinas                A 0.1 km de la playa   Booking.com
# 255            Tonsupa                A 0.7 km de la playa   Booking.com
# 256            Salinas                A 0.5 km de la playa   Booking.com
# 257            Salinas    a 3.7 km de: centro de la ciudad   Booking.com
# 258            Salinas                A 0.5 km de la playa   Booking.com
# 259            Salinas                A 0.1 km de la playa   Booking.com
#
# [260 rows x 7 columns]

# %%
try:
    with open('./data/hoteles.csv')as archivo_abierto:
        nombres = []   
        arreglo_lineas_archivo = archivo_abierto.readlines()
        for linea in arreglo_lineas_archivo:
            data = linea.split(',')
            nombres.append(data[0])
except Exception():
    print("No se pudo leer el archivo")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-11beb9f5aeb8> in <module>()
#       4
# ----> 5         arreglo_lineas_archivo = archivo_abierto.readlines()
#       6         for linea in arreglo_lineas_archivo:
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 872: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-11beb9f5aeb8> in <module>()
#       9
#      10
# ---> 11 except Exception():
#      12     print("No se pudo leer el archivo")
#
# TypeError: catching classes that do not inherit from BaseException is not allowed
